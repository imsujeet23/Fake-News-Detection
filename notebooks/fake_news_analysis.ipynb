# %% [markdown]
# # Fake News Detection Analysis
#
# This notebook supports Phase 2 experimentation for preprocessing, feature extraction, and model evaluation.

# %%
import pandas as pd
from pathlib import Path

project_root = Path('..').resolve()
raw_path = project_root / 'data' / 'raw' / 'fake_news.csv'
df = pd.read_csv(raw_path)
df.head()

# %%
from src.preprocessing import preprocess_dataframe

processed_df = preprocess_dataframe(df)
processed_df[['label', 'clean_text']].head()

# %%
from main import train_pipeline

metrics = train_pipeline()
metrics
